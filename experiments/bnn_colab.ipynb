# %% [markdown]
# # MNIST

# %%
# !git clone https://github.com/AidynKadyr/BinaryNet.pytorch.git
# !git clone -b cifar https://github.com/AidynKadyr/BinaryNet.pytorch.git

# %cd BinaryNet.pytorch
plot_dir = '/content/drive/MyDrive/2. Bocconi/THESIS/BinaryNet.pytorch/experiments/plots'
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'BinaryNet.pytorch'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 251 (delta 85), reused 148 (delta 42), pack-reused 55 (from 2)
# Receiving objects: 100% (251/251), 4.53 MiB | 7.35 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# /content/BinaryNet.pytorch
# Mounted at /content/drive

# %%
# !git pull origin cifar
# Out:
# From https://github.com/AidynKadyr/BinaryNet.pytorch
#  * branch            cifar      -> FETCH_HEAD
# Already up to date.

# %%
# Run experiment - use quotes around the path
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type ce \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %%
# Run experiment - use quotes around the path
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type ce \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
# Loading CIFAR-10 dataset...
# 100% 170M/170M [00:03<00:00, 44.3MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Creating VGG BinaryNet model...
# Using Cross-Entropy Loss
#
# Starting training for 10 epochs...
# ...
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.725438
#
# Test set: Average loss: 1.5623, Accuracy: 4491/10000 (45%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.546336
#
# Test set: Average loss: 1.4789, Accuracy: 4951/10000 (50%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.593256
#
# Test set: Average loss: 1.4186, Accuracy: 5096/10000 (51%)
#
# ...

# %%
# Test multiple b values
b_values = [1.0, 2.0, 5.0, 20.0]

results_summary = []

for b in b_values:
    print(f"\n{'='*80}")
    print(f"🧪 Testing Vlog with b={b}")
    print(f"{'='*80}\n")

    # !python experiments/mnist_mcmc_experiment.py \
        --loss-type vlog_fixed \
        --b-value {b} \
        --epochs 10 \
        --batch-size 512 \
        --num-workers 4 \
        --plot-dir "{plot_dir}"
# Out:
# ...
# 🧪 Testing Vlog with b=1.0
# ...
#
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss (fixed beta=1.0, b=1.0)
#
# Starting training for 10 epochs...
# ...
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.147257
# Train Epoch: 1 [51200/60000 (85%)]	Loss: -7.023912
#
# Test set: Average loss: -7.0326, Accuracy: 9249/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -6.761030
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -7.176949
#
# Test set: Average loss: -7.2396, Accuracy: 9347/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: -6.740409
# ...

# %%
# 3️⃣ Vlog with β-Annealing (β: 0.5→5.0) ⭐ NEW!
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with Beta-Annealing (beta: 0.5 -> 5.0, b=5.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: Beta = 0.5000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.754795
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.025367
#
# Test set: Average loss: -0.1439, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -0.016294
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -0.555450
#
# Test set: Average loss: -0.8138, Accuracy: 9269/10000 (93%)
#
# ...

# %%
# 3️⃣ Vlog with β-Annealing (β: 0.5→100) ⭐ NEW!
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 100 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with Beta-Annealing (beta: 0.5 -> 100.0, b=5.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: Beta = 0.5000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.754795
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.025367
#
# Test set: Average loss: -0.1439, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -0.179237
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -2.434820
#
# Test set: Average loss: -7.3794, Accuracy: 9263/10000 (93%)
#
# ...

# %%
# 3️⃣ Vlog with β-Annealing (β: 0.5→100) ⭐ NEW!
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 100 \
    --epochs 20 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with Beta-Annealing (beta: 0.5 -> 100.0, b=5.0)
#
# Starting training for 20 epochs...
# ...
# Epoch 1: Beta = 0.5000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.754795
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.025367
#
# Test set: Average loss: -0.1439, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -0.093907
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -1.818499
#
# Test set: Average loss: -1.7582, Accuracy: 9217/10000 (92%)
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type hinge \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Hinge Loss (margin=1.0)
#
# Starting training for 10 epochs...
# ...
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.999145
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.098567
#
# Test set: Average loss: 0.1602, Accuracy: 9182/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.102793
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.095579
#
# Test set: Average loss: 0.1282, Accuracy: 9274/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.130756
# ...

# %% [markdown]
# ## Hinge annealing

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type hinge_b_annealing \
    --hinge-b-start 1.0 \
    --hinge-b-end 100.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# 100% 9.91M/9.91M [00:00<00:00, 18.8MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 499kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.59MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 16.9MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Hinge Loss with b-Annealing (b: 1.0 -> 100.0, margin=1.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: b = 1.0000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.999145
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.098567
#
# Test set: Average loss: 0.1602, Accuracy: 9182/10000 (92%)
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type hinge_beta_annealing \
    --hinge-beta-start 0.5 \
    --hinge-beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Hinge Loss with β-Annealing (beta: 0.5 -> 5.0, margin=1.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: Beta = 0.5000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.499573
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.042436
#
# Test set: Average loss: 0.0785, Accuracy: 9211/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.090725
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.110387
#
# Test set: Average loss: 0.1296, Accuracy: 9310/10000 (93%)
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type hinge_both_annealing \
    --hinge-b-start 1.0 \
    --hinge-b-end 100.0 \
    --hinge-beta-start 0.5 \
    --hinge-beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Hinge Loss with BOTH b-Annealing & β-Annealing
#   b: 1.0 -> 100.0 (exponential)
#   β: 0.5 -> 5.0 (linear)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: Beta = 0.5000
# Epoch 1: b = 1.0000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.499573
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.042436
#
# Test set: Average loss: 0.0785, Accuracy: 9211/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.221585
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.450787
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 100.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with b-Annealing (b: 1.0 -> 100.0, beta=1.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: b = 1.0000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.147257
# Train Epoch: 1 [51200/60000 (85%)]	Loss: -7.023912
#
# Test set: Average loss: -7.0326, Accuracy: 9249/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -5.754858
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -9.346138
#
# Test set: Average loss: -9.6106, Accuracy: 9271/10000 (93%)
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 10.0 \
    --vlog-b-end 1.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with b-Annealing (b: 10.0 -> 1.0, beta=1.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: b = 10.0000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 10.835954
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 3.284034
#
# Test set: Average loss: 3.2903, Accuracy: 8903/10000 (89%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.340854
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 1.090715
#
# Test set: Average loss: 1.4241, Accuracy: 9062/10000 (91%)
#
# ...

# %%
# !python experiments/mnist_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 10.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"
# Out:
# ✅ Using GPU: Tesla T4
#    Data workers: 4
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Using Vlog Loss with b-Annealing (b: 1.0 -> 10.0, beta=1.0)
#
# Starting training for 10 epochs...
# ...
# Epoch 1: b = 1.0000
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.147257
# Train Epoch: 1 [51200/60000 (85%)]	Loss: -7.023912
#
# Test set: Average loss: -7.0326, Accuracy: 9249/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: -7.307493
# Train Epoch: 2 [51200/60000 (85%)]	Loss: -8.528488
#
# Test set: Average loss: -8.6997, Accuracy: 9347/10000 (93%)
#
# ...

# %% [markdown]
# # CIFAR

# %%
# !git clone https://github.com/AidynKadyr/BinaryNet.pytorch.git
# !git clone -b cifar https://github.com/AidynKadyr/BinaryNet.pytorch.git

# %cd BinaryNet.pytorch
plot_dir = '/content/drive/MyDrive/2. Bocconi/THESIS/BinaryNet.pytorch/experiments/plots'
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## CIFAR-10 Experiments
#
# Running the same comprehensive set of experiments as MNIST, but on CIFAR-10 dataset.

# %% [markdown]
# ### 1️⃣ Cross-Entropy Baseline

# %%
# Cross-Entropy baseline for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type ce \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 2️⃣ Vlog Loss - Testing Multiple b Values

# %%
# Test multiple b values for CIFAR-10
b_values = [1.0, 2.0, 5.0, 20.0]

results_summary = []

for b in b_values:
    print(f"\n{'='*80}")
    print(f"🧪 Testing Vlog with b={b}")
    print(f"{'='*80}\n")

    # !python experiments/cifar10_mcmc_experiment.py \
        --loss-type vlog_fixed \
        --b-value {b} \
        --epochs 10 \
        --batch-size 512 \
        --num-workers 4 \
        --plot-dir "{plot_dir}"

# %% [markdown]
# ### 3️⃣ Vlog with β-Annealing (β: 0.5→5.0)

# %%
# Vlog with β-Annealing (β: 0.5→5.0) for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 4️⃣ Vlog with β-Annealing (β: 0.5→100)

# %%
# Vlog with β-Annealing (β: 0.5→100) for CIFAR-10 - 10 epochs
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 100 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %%
# Vlog with β-Annealing (β: 0.5→100) for CIFAR-10 - 20 epochs
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_annealing \
    --b-value 5.0 \
    --beta-start 0.5 \
    --beta-end 100 \
    --epochs 20 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 5️⃣ Hinge Loss

# %%
# Standard Hinge Loss for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type hinge \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 6️⃣ Hinge Loss with Annealing

# %%
# Hinge with b-Annealing for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type hinge_b_annealing \
    --hinge-b-start 1.0 \
    --hinge-b-end 100.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %%
# Hinge with β-Annealing for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type hinge_beta_annealing \
    --hinge-beta-start 0.5 \
    --hinge-beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %%
# Hinge with BOTH b & β Annealing for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type hinge_both_annealing \
    --hinge-b-start 1.0 \
    --hinge-b-end 100.0 \
    --hinge-beta-start 0.5 \
    --hinge-beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 7️⃣ Vlog with b-Annealing

# %%
# Vlog with b-Annealing (1.0→100.0) for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 100.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"

# %%
# Vlog with b-Annealing (10.0→1.0) for CIFAR-10 - reversed annealing
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 10.0 \
    --vlog-b-end 1.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"

# %%
# Vlog with b-Annealing (1.0→10.0) for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_b_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 10.0 \
    --epochs 10 \
    --batch-size 512 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# ### 8️⃣ Vlog with BOTH Annealing (b & β)

# %%
# Vlog with BOTH b & β Annealing for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_both_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 100.0 \
    --beta-start 0.5 \
    --beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %%
# !git pull origin cifar

# %%
# Vlog with BOTH b & β Annealing for CIFAR-10
# !python experiments/cifar10_mcmc_experiment.py \
    --loss-type vlog_both_annealing \
    --vlog-b-start 1.0 \
    --vlog-b-end 100.0 \
    --beta-start 0.5 \
    --beta-end 5.0 \
    --epochs 10 \
    --batch-size 512 \
    --num-workers 4 \
    --plot-dir "{plot_dir}"

# %% [markdown]
# improvement: regime at the edge of overparametrization. en.
# our method wouldh help:
# fix the dataset do exploration from size of the model. if there is a regime in the size compared to baselines.
